# %% [markdown]
# # PySpark 4
#
# !/home/user/pysparkenv/bin/pip install <модуль>
#
# или
#
# %pip install <модуль

# %% [markdown]
# ## Версия

# %%
# !python3 --version
# Out:
# Python 3.14.4

# %%
! ~/pysparkenv/bin/python3 --version
# Out:
# Python 3.14.4

# %% [markdown]
# ## Kernel

# %%
# !pwd
# Out:
# /home/chul/WORKSHOP/PYSPARK

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3               /home/chul/mainenv/share/jupyter/kernels/python3
#   apache_toree_scala    /home/chul/.local/share/jupyter/kernels/apache_toree_scala
#   pydevenv              /home/chul/.local/share/jupyter/kernels/pydevenv
#   pymlenv               /home/chul/.local/share/jupyter/kernels/pymlenv
#   pysparkenv            /home/chul/.local/share/jupyter/kernels/pysparkenv
#   pytorchenv            /home/chul/.local/share/jupyter/kernels/pytorchenv
#   scala                 /home/chul/.local/share/jupyter/kernels/scala

# %%
! cat ~/.local/share/jupyter/kernels/pysparkenv/kernel.json
# Out:
# {
#  "argv": [
#   "/home/chul/pysparkenv/bin/python",
#   "-Xfrozen_modules=off",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "display_name": "PySpark",
#  "language": "python",
#  "metadata": {
#   "debugger": true
#  },
#  "kernel_protocol_version": "5.5"
# }

# %%
import os
import json

# %%
# настройки kernel
path = os.path.expanduser('~/.local/share/jupyter/kernels/pysparkenv/kernel.json')
with open(path) as kernel_json:
    kernel_data = json.load(kernel_json)

# %%
kernel_data
# Out:
# {'argv': ['/home/chul/pysparkenv/bin/python',
#   '-Xfrozen_modules=off',
#   '-m',
#   'ipykernel_launcher',
#   '-f',
#   '{connection_file}'],
#  'display_name': 'PySpark',
#  'language': 'python',
#  'metadata': {'debugger': True},
#  'kernel_protocol_version': '5.5'}

# %% [markdown]
# ## SPARK

# %%
import os
import sys
spark_home = os.environ.get('SPARK_HOME', None)
sys.path.insert(0, spark_home + "python")
os.environ["SPARK_LOCAL_IP"]='localhost'
from pyspark import SparkContext, SparkConf#, HiveContext
conf = SparkConf()\
             .setAppName("Example Spark")\
             .setMaster("local[2]")\
             .setAppName("CountingSheep")\
             .set("spark.sql.catalogImplementation", "hive")
sc = SparkContext(conf=conf)
sc.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/27 21:03:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/27 21:03:43 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
exec(open(os.path.join(spark_home, 'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 4.1.1
#       /_/
#
# Using Python version 3.14.4 (main, Apr  8 2026 04:02:31)
# Spark context Web UI available at http://localhost:4041
# Spark context available as 'sc' (master = local[2], app id = local-1777313023639).
# SparkSession available as 'spark'.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://localhost:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CountingSheep</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.stop()
