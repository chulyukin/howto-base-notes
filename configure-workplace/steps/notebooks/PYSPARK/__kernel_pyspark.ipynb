# %% [markdown]
# # PySpark 3
#
# !/home/user/pysparkenv/bin/pip install <модуль>
#
# или
#
# %pip install <модуль

# %% [markdown]
# ## Версия

# %%
# !python3 --version
# Out:
# Python 3.14.4

# %%
! ~/pysparkenv/bin/python3 --version
# Out:
# Python 3.14.4

# %% [markdown]
# ## Kernel

# %%
# !pwd
# Out:
# /home/user/WORKSHOP/PYSPARK

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3               /home/user/mainenv/share/jupyter/kernels/python3
#   apache_toree_scala    /home/user/.local/share/jupyter/kernels/apache_toree_scala
#   pydevenv              /home/user/.local/share/jupyter/kernels/pydevenv
#   pymlenv               /home/user/.local/share/jupyter/kernels/pymlenv
#   pysparkenv            /home/user/.local/share/jupyter/kernels/pysparkenv
#   pytorchenv            /home/user/.local/share/jupyter/kernels/pytorchenv
#   scala                 /home/user/.local/share/jupyter/kernels/scala

# %%
! cat ~/.local/share/jupyter/kernels/pysparkenv/kernel.json
# Out:
# {
#  "argv": [
#   "~/pysparkenv/bin/python",
#   "-Xfrozen_modules=off",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "env":{
#         "SPARK_HOME":"/opt/spark",
#         "PYSPARK_PYTHON":"$HOME/pysparkenv/bin/python"
# },
#  "display_name": "PySpark",
#  "language": "python",
#  "metadata": {
#   "debugger": true
#  }
# }

# %%
import os
import json

# %%
# настройки kernel
path = os.path.expanduser('~/.local/share/jupyter/kernels/pysparkenv/kernel.json')
with open(path) as kernel_json:
    kernel_data = json.load(kernel_json)

# %%
kernel_data
# Out:
# {'argv': ['~/pysparkenv/bin/python',
#   '-Xfrozen_modules=off',
#   '-m',
#   'ipykernel_launcher',
#   '-f',
#   '{connection_file}'],
#  'env': {'SPARK_HOME': '/opt/spark',
#   'PYSPARK_PYTHON': '$HOME/pysparkenv/bin/python'},
#  'display_name': 'PySpark',
#  'language': 'python',
#  'metadata': {'debugger': True}}

# %% [markdown]
# ## Модули

# %%
!~/pysparkenv/bin/pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /home/user/pysparkenv/lib/python3.14/site-packages (24.0.0)

# %%
import pyarrow as pa

# %%
import os
import sys
spark_home = os.environ.get('SPARK_HOME', None)
sys.path.insert(0, spark_home + "python")
os.environ["SPARK_LOCAL_IP"]='localhost'
from pyspark import SparkContext, SparkConf#, HiveContext
conf = SparkConf()\
             .setAppName("Example Spark")\
             .setMaster("local[2]")\
             .setAppName("CountingSheep")\
             .set("spark.sql.catalogImplementation", "hive")
sc = SparkContext(conf=conf)
sc.setLogLevel("ERROR")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/26 20:30:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
exec(open(os.path.join(spark_home, 'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.5.8
#       /_/
#
# Using Python version 3.14.4 (main, Apr  8 2026 04:02:31)
# Spark context Web UI available at http://localhost:4040
# Spark context available as 'sc' (master = local[2], app id = local-1777224633991).
# SparkSession available as 'spark'.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://localhost:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.8</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CountingSheep</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.stop()
