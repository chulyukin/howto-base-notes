# %% [markdown]
# # PySpark 3

# %% [markdown]
# ## Версия

# %%
# !python3 --version
# Out:
# Python 3.13.7

# %%
! ~/pysparkenv/bin/python3 --version
# Out:
# Python 3.13.7

# %% [markdown]
# ## Kernel

# %%
# !pwd
# Out:
# /home/vboxuser/WORKSHOP/PYSPARK

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3       /home/vboxuser/mainenv/share/jupyter/kernels/python3
#   pydevenv      /home/vboxuser/.local/share/jupyter/kernels/pydevenv
#   pymlenv       /home/vboxuser/.local/share/jupyter/kernels/pymlenv
#   pysparkenv    /home/vboxuser/.local/share/jupyter/kernels/pysparkenv
#   pytorchenv    /home/vboxuser/.local/share/jupyter/kernels/pytorchenv

# %%
! cat ~/.local/share/jupyter/kernels/pysparkenv/kernel.json
# Out:
# {
#  "argv": [
#   "~/pysparkenv/bin/python",
#   "-Xfrozen_modules=off",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "env":{
#         "SPARK_HOME":"/opt/spark",
#         "PYSPARK_PYTHON":"$HOME/pysparkenv/bin/python"
# },
#  "display_name": "PySpark",
#  "language": "python",
#  "metadata": {
#   "debugger": true
#  }
# }

# %%
import os
import json

# %%
# настройки kernel
path = os.path.expanduser('~/.local/share/jupyter/kernels/pysparkenv/kernel.json')
with open(path) as kernel_json:
    kernel_data = json.load(kernel_json)

# %%
kernel_data
# Out:
# {'argv': ['~/pysparkenv/bin/python',
#   '-Xfrozen_modules=off',
#   '-m',
#   'ipykernel_launcher',
#   '-f',
#   '{connection_file}'],
#  'env': {'SPARK_HOME': '/opt/spark',
#   'PYSPARK_PYTHON': '$HOME/pysparkenv/bin/python'},
#  'display_name': 'PySpark',
#  'language': 'python',
#  'metadata': {'debugger': True}}

# %% [markdown]
# ## Модули

# %%
# Установка seaborn
!~/pymlenv/bin/pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/vboxuser/pymlenv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/vboxuser/pymlenv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
