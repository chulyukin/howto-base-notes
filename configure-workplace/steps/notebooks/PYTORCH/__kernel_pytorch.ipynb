# %% [markdown]
# # PyTorch
#
# !/home/user/pytorchenv/bin/pip install <модуль>
#
# или
#
# %pip install <модуль

# %% [markdown]
# ## Версия

# %%
# !python3 --version
# Out:
# Python 3.14.4

# %%
!~/pytorchenv/bin/python3 --version
# Out:
# Python 3.14.4

# %% [markdown]
# ## Kernel

# %%
# !pwd
# Out:
# /home/user/WORKSHOP/PYTORCH

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3               /home/user/mainenv/share/jupyter/kernels/python3
#   apache_toree_scala    /home/user/.local/share/jupyter/kernels/apache_toree_scala
#   pydevenv              /home/user/.local/share/jupyter/kernels/pydevenv
#   pymlenv               /home/user/.local/share/jupyter/kernels/pymlenv
#   pysparkenv            /home/user/.local/share/jupyter/kernels/pysparkenv
#   pytorchenv            /home/user/.local/share/jupyter/kernels/pytorchenv
#   scala                 /home/user/.local/share/jupyter/kernels/scala

# %%
! cat ~/.local/share/jupyter/kernels/pytorchenv/kernel.json
# Out:
# {
#  "argv": [
#   "/home/user/pytorchenv/bin/python",
#   "-Xfrozen_modules=off",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "display_name": "PyTorch",
#  "language": "python",
#  "metadata": {
#   "debugger": true
#  },
#  "kernel_protocol_version": "5.5"
# }

# %%
import os
import json

# %%
# настройки kernel
path = os.path.expanduser('~/.local/share/jupyter/kernels/pytorchenv/kernel.json')
with open(path) as kernel_json:
    kernel_data = json.load(kernel_json)

# %%
kernel_data
# Out:
# {'argv': ['/home/user/pytorchenv/bin/python',
#   '-Xfrozen_modules=off',
#   '-m',
#   'ipykernel_launcher',
#   '-f',
#   '{connection_file}'],
#  'display_name': 'PyTorch',
#  'language': 'python',
#  'metadata': {'debugger': True},
#  'kernel_protocol_version': '5.5'}

# %% [markdown]
# ## Модули

# %%
# Если используестя графический процессор (GPU) NVidia
!~/pytorchenv/bin/pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
#   Using cached https://download-r2.pytorch.org/whl/cu126/torch-2.11.0%2Bcu126-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ...
#   Using cached https://download-r2.pytorch.org/whl/cu126/torchvision-0.26.0%2Bcu126-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached https://download-r2.pytorch.org/whl/cu126/torchaudio-2.11.0%2Bcu126-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# ...
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...

# %%
# Если не используестя графический процессор (GPU) NVidia
!~/pytorchenv/bin/pip install torch torchvision torchaudio

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.11.0+cu126

# %%
print("CUDA avaivable:", torch.cuda.is_available())
# Out:
# CUDA avaivable: True
